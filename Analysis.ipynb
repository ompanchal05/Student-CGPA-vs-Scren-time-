# %%
#importing the Libraries

import pandas as pd 
import numpy as np 
import seaborn as sns

# %%
#importing the data in the notebook

df = pd.read_csv("Student_Performance_2026.csv")
df
# Out:
#     student_ID  Age  Gender  daily_screen_time_hours  social_media_hours  \
# 0         S011   23  Female                      6.2                 2.5
# 1         S012   24  Female                      4.9                 2.0
# 2         S013   18  Female                      7.9                 3.2
# 3         S014   17    Male                     10.0                 4.0
# 4         S015   23  Female                      7.7                 3.1
# ..         ...  ...     ...                      ...                 ...
# 541       S552   17    Male                      4.1                 1.6
# 542       S553   24  Female                      6.4                 2.6
# 543       S554   17    Male                      8.3                 3.3
# 544       S555   21  Female                      9.8                 3.9
# 545       S556   24  Female                      8.7                 3.5
#
#      online_study_hours  gaming_hours  sleep_hours  attendance_percentage  \
# ...

# %%
#Seeing Null Values 

df.isnull().sum()
# Out:
# student_ID                 0
# Age                        0
# Gender                     0
# daily_screen_time_hours    0
# social_media_hours         0
# online_study_hours         0
# gaming_hours               0
# sleep_hours                0
# attendance_percentage      0
# offline_study_hours        0
# previous_sem_CGPA          0
# current_sem_CGPA           0
# dtype: int64

# %%
# Drop the rows if NUll 
df = df.dropna()

# %%
# Checking the Duplicate Records 
df.duplicated().sum()
# Out:
# np.int64(0)
